# %%
from micrograd_adjusted.nn import Neuron
from graphviz import Digraph

# %%
xs = [
    [2., 3., -1.],
    [3., -1., 0.5],
    [0.5, 1., 1.],
    [1., 1., -1.]
]
ys = [1., -1., -1., 1.]


from micrograd_adjusted.nn import MLP

n = MLP(3, [4, 6, 5, 3, 1])

n.fit(xs, ys)
# Out:
# Iteration: 0, Loss: 4.155006034842828
# Iteration: 100, Loss: 0.050414207644566625
# Iteration: 200, Loss: 0.0204230576162884
# Iteration: 300, Loss: 0.012317024600804692
# Iteration: 400, Loss: 0.0086750508317029
# Iteration: 500, Loss: 0.006638201796608557
# Iteration: 600, Loss: 0.005348382920806224
# Iteration: 700, Loss: 0.004463213660886309
# Iteration: 800, Loss: 0.003820492838579298
# Iteration: 900, Loss: 0.003333904316705825

# %%
print()
print(ys)

print(n.predict(xs))
# Out:
# [1.0, -1.0, -1.0, 1.0]
# [0.972946267577513, -0.9703699050047053, -0.9791578794877425, 0.9698465879483649]

# %%
n.draw()
# Out:
# Graph rendered to nn-output\nn-graph-out.svg
